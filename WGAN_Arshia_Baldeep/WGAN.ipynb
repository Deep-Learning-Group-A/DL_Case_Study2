# %% [markdown]
# <center><h1>WGAN Model</h1></center>

# %% [markdown]
# #### Model Summary

# %% [markdown]
# ##### 1. Base Model

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = "./Generated_Images/BaseModel.png"

img = mpimg.imread(image_path)
plt.imshow(img)
plt.title('Generated Images for Base Model')
plt.axis('off')  
plt.show()

# %% [markdown]
# ##### 2. Model Tuning 1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = "./Generated_Images/Tuning1.png"

img = mpimg.imread(image_path)
plt.imshow(img)
plt.title('Generated Images for Tuning 1')
plt.axis('off')  
plt.show()

# %%
# File path
file_path = "metrics.txt"

# Read the file line by line
with open(file_path, "r") as file:
    lines = file.readlines()

# Print the content
for line in lines:
    print(line.strip())  # Remove any leading/trailing whitespace
# Out:
# FID Score Base Model: 369.6523
# Inception Score Base Model: 2.1254 ± 0.0471
# FID Score for Tuning 1: 440.4061
# Inception Score for Tuning 1: 1.4904 ± 0.0400

# %% [markdown]
# ## MECE
# | Name               | Task Done      |
# |-----------------------|----------------------------|
# | Arshia | Model Building and Evaluation of Base model and Tuning 1 of WGAN |
# | Baldeep | Model Building and Evaluation of Tuning 2 and Tuning 3 of WGAN |
# | Shubham | Deployment |
# | Sameer | Deployment |
# | Aman | DCGAN |
# | Ramandeep | DCGAN |
# | Abhishek | VAE |
# | Ram Krishna | VAE |
# | Palash | cGAN |
# | Govind | cGAN |

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import os
import json
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision.utils as vutils
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms, datasets
import random
from PIL import Image
import torch.nn as nn
import torch.optim as optim
import torch
from torchvision.models import inception_v3
from torcheval.metrics import FrechetInceptionDistance
from torchvision.transforms import functional as F

# %%
# !pip install torcheval

# %%
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"CUDA Version: {torch.version.cuda}")
print(f"GPU Name: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA Available: True
# CUDA Version: 12.1
# GPU Name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
photos_df = pd.read_json(r'C:\Users\arshi\Desktop\AI & DS\Term3\DL\Assignments\Graded4\photos.json', lines=True)

# %%
photos_df.head()
# Out:
#                  photo_id             business_id  \
# 0  zsvj7vloL4L5jhYyPIuVwg  Nk-SJhPlDBkAZvfsADtccA
# 1  HCUdRJHHm_e0OCTlZetGLg  yVZtL5MmrpiivyCIrVkGgA
# 2  vkr8T0scuJmGVvN2HJelEA  _ab50qdWOk0DdB6XOrBitw
# 3  pve7D6NUrafHW3EAORubyw  SZU9c8V2GuREDN5KgyHFJw
# 4  H52Er-uBg6rNrHcReWTD2w  Gzur0f0XMkrVxIwYJvOt2g
#
#                                              caption    label
# 0  Nice rock artwork everywhere and craploads of ...   inside
# 1                                                     outside
# 2                                     oyster shooter    drink
# 3                                      Shrimp scampi     food
# 4                                                        food

# %%
photos_df['label'].unique()
# Out:
# array(['inside', 'outside', 'drink', 'food', 'menu'], dtype=object)

# %%
count_type = []
for i in photos_df['label'].unique():
    count_type.append(photos_df['label'].tolist().count(i))
    print(f"{i} class - {photos_df['label'].tolist().count(i)} images")
# Out:
# inside class - 56031 images
# outside class - 18569 images
# drink class - 15670 images
# food class - 108152 images
# menu class - 1678 images

# %%
plt.figure(figsize=(8, 5))
plt.bar(photos_df['label'].unique(), count_type, color=['blue', 'green', 'red', 'violet', 'purple'])
# Out:
# <BarContainer object of 5 artists>

# %%
# Dataset Class
class YelpDataset(Dataset):
    def __init__(self, image_folder, json_file, label_filter, transform=None):
        self.image_folder = image_folder
        self.transform = transform
        self.label_filter = label_filter
        self.image_files = []

        with open(json_file, 'r') as f:
            for line in f:
                try:
                    entry = json.loads(line.strip())
                    if entry.get('label') == self.label_filter:
                        image_filename = entry['photo_id'] + '.jpg'
                        image_path = os.path.join(image_folder, image_filename)
                        if os.path.isfile(image_path):
                            try:
                                with Image.open(image_path) as img:
                                    img.verify()
                                self.image_files.append(image_filename)
                            except Exception as e:
                                print(f"Skipping corrupted image {image_filename}: {str(e)}")
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON line: {line.strip()} -> {str(e)}")

        print(f"Found {len(self.image_files)} valid images with label '{self.label_filter}'")
        
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        while True:
            try:
                img_path = os.path.join(self.image_folder, self.image_files[idx])
                image = Image.open(img_path).convert('RGB')
                if self.transform:
                    image = self.transform(image)
                return image
            except Exception as e:
                print(f"Error loading image {self.image_files[idx]}: {str(e)}")
                idx = (idx + 1) % len(self.image_files)

# %%
photos = r'C:\Users\arshi\Desktop\AI & DS\Term3\DL\Assignments\Graded4\photos'
metadata = r'C:\Users\arshi\Desktop\AI & DS\Term3\DL\Assignments\Graded4\photos.json'
label_filter = "food"

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # Normalize to [-1, 1]
])

# %%
dataset = YelpDataset(image_folder=photos, json_file=metadata, label_filter=label_filter, transform=transform)
# Out:
# Skipping corrupted image ydm3g1wUWSxJnMPgHk2JhQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\ydm3g1wUWSxJnMPgHk2JhQ.jpg'
# Skipping corrupted image JGpfPj8VEvnq1B-Xqr3w-A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\JGpfPj8VEvnq1B-Xqr3w-A.jpg'
# Skipping corrupted image bf3ymV0YgP7B6rEoriaU2w.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\bf3ymV0YgP7B6rEoriaU2w.jpg'
# Skipping corrupted image juDNZOOnkgG3QINFrulsAg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\juDNZOOnkgG3QINFrulsAg.jpg'
# Skipping corrupted image 9X4YPM8nYFjf7hY8xUdc6Q.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\9X4YPM8nYFjf7hY8xUdc6Q.jpg'
# Skipping corrupted image N6hL8FQ84A2DznF2S2Lp7g.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\N6hL8FQ84A2DznF2S2Lp7g.jpg'
# Skipping corrupted image pY32hIagdxrL4Nsi959EQg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\pY32hIagdxrL4Nsi959EQg.jpg'
# Skipping corrupted image cNkUV0sInfh_Py5PP8SHtQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\cNkUV0sInfh_Py5PP8SHtQ.jpg'
# Skipping corrupted image Pk87_8Yndygr4LRUD_H7Hg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\Pk87_8Yndygr4LRUD_H7Hg.jpg'
# Skipping corrupted image ke4ohxa93GJz0KH9H2kwsQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\ke4ohxa93GJz0KH9H2kwsQ.jpg'
# Skipping corrupted image rLafN9k3_AF5lZU0cs3LZg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\rLafN9k3_AF5lZU0cs3LZg.jpg'
# Skipping corrupted image -YAvSvGUs2ugiJUvIRO6Jw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\-YAvSvGUs2ugiJUvIRO6Jw.jpg'
# Skipping corrupted image feUGw0P5byOq4U40C77tyQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\feUGw0P5byOq4U40C77tyQ.jpg'
# Skipping corrupted image pW1IPuTdLIUB61goirbXaA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\pW1IPuTdLIUB61goirbXaA.jpg'
# Skipping corrupted image RLtBKD2rlfTaELWejmLBCA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\RLtBKD2rlfTaELWejmLBCA.jpg'
# Skipping corrupted image IB2ZjqjtS1W_DadQoPPdgg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\IB2ZjqjtS1W_DadQoPPdgg.jpg'
# Skipping corrupted image 43fHlHSYQ_79OBJW1aVUxA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\43fHlHSYQ_79OBJW1aVUxA.jpg'
# Skipping corrupted image QhATx1B1n8uf8C6siMNTfA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\QhATx1B1n8uf8C6siMNTfA.jpg'
# Skipping corrupted image 9RDbbAZB0HnL4hndCWB58w.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\9RDbbAZB0HnL4hndCWB58w.jpg'
# Skipping corrupted image 1wd_eyhMrTqUmicDmn4_Kw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\1wd_eyhMrTqUmicDmn4_Kw.jpg'
# Skipping corrupted image W94rrCn0O5K1lkfD26m4tw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\W94rrCn0O5K1lkfD26m4tw.jpg'
# Skipping corrupted image n6Q9vNuxz7786ESEfautxQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\n6Q9vNuxz7786ESEfautxQ.jpg'
# Skipping corrupted image YW1WMOkVbdFBrixDnKgoqA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\YW1WMOkVbdFBrixDnKgoqA.jpg'
# Skipping corrupted image hjEfal2a1DWRDu8_AUDLNg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\hjEfal2a1DWRDu8_AUDLNg.jpg'
# Skipping corrupted image 0TpeNZPs3Gu8s30KVXudcg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\0TpeNZPs3Gu8s30KVXudcg.jpg'
# Skipping corrupted image AMSyCOP3-Eb_ivNA8w1Vhw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\AMSyCOP3-Eb_ivNA8w1Vhw.jpg'
# Skipping corrupted image TvD36_DdnyCJuXV1SSt3_Q.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\TvD36_DdnyCJuXV1SSt3_Q.jpg'
# Skipping corrupted image rrfwGSwt3eHxxypfu5PGTA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\rrfwGSwt3eHxxypfu5PGTA.jpg'
# Skipping corrupted image qMlGILrsrzhMDxajNYiyIA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\qMlGILrsrzhMDxajNYiyIA.jpg'
# Skipping corrupted image jU-dKl2Ye4L_5x602yoctQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\jU-dKl2Ye4L_5x602yoctQ.jpg'
# Skipping corrupted image TN4-gAea6ejAdZ-NzYXxng.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\TN4-gAea6ejAdZ-NzYXxng.jpg'
# Skipping corrupted image IkGbGxI8IoOCuVsNB0VLrA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\IkGbGxI8IoOCuVsNB0VLrA.jpg'
# Skipping corrupted image nKJ7yiPc0E_DJNtNxmCrhg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\nKJ7yiPc0E_DJNtNxmCrhg.jpg'
# Skipping corrupted image E7Wpzn-1fCnVJ8_zKpecPQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\E7Wpzn-1fCnVJ8_zKpecPQ.jpg'
# Skipping corrupted image MduVueqYTBlEkX-axrh1ug.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\MduVueqYTBlEkX-axrh1ug.jpg'
# Skipping corrupted image ytJ4lihJrvyzMMRG-WwDNw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\ytJ4lihJrvyzMMRG-WwDNw.jpg'
# Skipping corrupted image -BIybLxzoFt2d2zbYRcfHA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\-BIybLxzoFt2d2zbYRcfHA.jpg'
# Skipping corrupted image RhC7TNmFvbR9GWrlrl5dsA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\RhC7TNmFvbR9GWrlrl5dsA.jpg'
# Skipping corrupted image OK6HsALzFcBAUlrroKHZGg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\OK6HsALzFcBAUlrroKHZGg.jpg'
# Skipping corrupted image CBxmBYD_5CXIL_F-2PDqmA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\CBxmBYD_5CXIL_F-2PDqmA.jpg'
# Skipping corrupted image K6pfRNwGodm1m1gFVQlj-Q.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\K6pfRNwGodm1m1gFVQlj-Q.jpg'
# Skipping corrupted image JoQ5xekjQUkj8rukJIzqgg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\JoQ5xekjQUkj8rukJIzqgg.jpg'
# Skipping corrupted image yFjqHyOaNFwzIWTV8EE9hg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\yFjqHyOaNFwzIWTV8EE9hg.jpg'
# Skipping corrupted image hclqCX1FWcV_TtJJoI3BpQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\hclqCX1FWcV_TtJJoI3BpQ.jpg'
# Skipping corrupted image JG5s_bvRF1cSWf1fk9lTbw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\JG5s_bvRF1cSWf1fk9lTbw.jpg'
# Skipping corrupted image kjMBhxBXOUE7SSUQb-YQbw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\kjMBhxBXOUE7SSUQb-YQbw.jpg'
# Skipping corrupted image DMCTwC3UT2w5QzHOQoqBPw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\DMCTwC3UT2w5QzHOQoqBPw.jpg'
# Skipping corrupted image 1MOGQBWogR8oJr1WgERi9g.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\1MOGQBWogR8oJr1WgERi9g.jpg'
# Skipping corrupted image WGmGujPl5BmR_fCUZnoe9w.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\WGmGujPl5BmR_fCUZnoe9w.jpg'
# Skipping corrupted image w5ABnSadHC8z1lthMQBaBQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\w5ABnSadHC8z1lthMQBaBQ.jpg'
# Skipping corrupted image zTzdu2QqLozHpW_qYWF84w.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\zTzdu2QqLozHpW_qYWF84w.jpg'
# Skipping corrupted image 2S78q98b_VpBD7vkrDE5-A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\2S78q98b_VpBD7vkrDE5-A.jpg'
# Skipping corrupted image yhztPWh5IhaePpUQJNW-dQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\yhztPWh5IhaePpUQJNW-dQ.jpg'
# Skipping corrupted image AkiGRjaMKHdJyV7bdHsQjw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\AkiGRjaMKHdJyV7bdHsQjw.jpg'
# Skipping corrupted image NKEFWvRriK-LvagPz2QRxw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\NKEFWvRriK-LvagPz2QRxw.jpg'
# Skipping corrupted image c73YwNh1JsYR5Hz-u_bOrg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\c73YwNh1JsYR5Hz-u_bOrg.jpg'
# Skipping corrupted image PjfJoBrEFgDrxiJy8nyatA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\PjfJoBrEFgDrxiJy8nyatA.jpg'
# Skipping corrupted image LXT4hCf1lRyUeM4HDBaSvg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\LXT4hCf1lRyUeM4HDBaSvg.jpg'
# Skipping corrupted image XX6ujA9CcB5s9y9wCy67-Q.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\XX6ujA9CcB5s9y9wCy67-Q.jpg'
# Skipping corrupted image IUsKp87a-v9Yhx6Ftg1m5A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\IUsKp87a-v9Yhx6Ftg1m5A.jpg'
# Skipping corrupted image QRUo4vqUu3X9V4eIqBpY8A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\QRUo4vqUu3X9V4eIqBpY8A.jpg'
# Skipping corrupted image Y3lA41pnMkQNGfyREkf6SA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\Y3lA41pnMkQNGfyREkf6SA.jpg'
# Skipping corrupted image 5q-sAvIPl0yNeuAbNBPM1g.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\5q-sAvIPl0yNeuAbNBPM1g.jpg'
# Skipping corrupted image PFD3ykdI1WVhvZ8IX4PmLQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\PFD3ykdI1WVhvZ8IX4PmLQ.jpg'
# Skipping corrupted image MZj64XNUN6Og178-6XYR6g.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\MZj64XNUN6Og178-6XYR6g.jpg'
# Skipping corrupted image l_rMdwgrvjm2PyHyXBcBTw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\l_rMdwgrvjm2PyHyXBcBTw.jpg'
# Skipping corrupted image IExxMfr1h0bxw54jsanyKA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\IExxMfr1h0bxw54jsanyKA.jpg'
# Skipping corrupted image -NGY_19QK2zq913HdiYc5A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\-NGY_19QK2zq913HdiYc5A.jpg'
# Skipping corrupted image aUDiJhcFKt0exhyj4Q23Ow.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\aUDiJhcFKt0exhyj4Q23Ow.jpg'
# Skipping corrupted image LhLfsQtYwJ5OmEzilubhXQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\LhLfsQtYwJ5OmEzilubhXQ.jpg'
# Skipping corrupted image l2vR3PyVMF3pgIERdDEuiQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\l2vR3PyVMF3pgIERdDEuiQ.jpg'
# Skipping corrupted image 0fac-NlXqfBO2pWRkmM9aw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\0fac-NlXqfBO2pWRkmM9aw.jpg'
# Skipping corrupted image O0bVFyP58TOEix6IjERXQA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\O0bVFyP58TOEix6IjERXQA.jpg'
# Skipping corrupted image t_sV6mI4oNvbvohhZAyeuA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\t_sV6mI4oNvbvohhZAyeuA.jpg'
# Skipping corrupted image _exWW0g4Svg1Eo2YWsGzbg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\_exWW0g4Svg1Eo2YWsGzbg.jpg'
# Skipping corrupted image -ZkmgGLJ7AJTjy96nocMNw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\-ZkmgGLJ7AJTjy96nocMNw.jpg'
# Skipping corrupted image JZZ716oX6_MqH6L_MkWK-A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\JZZ716oX6_MqH6L_MkWK-A.jpg'
# Skipping corrupted image 7xcWPjcE4mxoQ1AjvvKJZg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\7xcWPjcE4mxoQ1AjvvKJZg.jpg'
# Skipping corrupted image lrfy4UVIWtj0xwboLgUreQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\lrfy4UVIWtj0xwboLgUreQ.jpg'
# Skipping corrupted image tlp6LCLDsvL1GjO_kW_plQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\tlp6LCLDsvL1GjO_kW_plQ.jpg'
# Skipping corrupted image B7xR9CuhRpP52PoehQHVow.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\B7xR9CuhRpP52PoehQHVow.jpg'
# Skipping corrupted image qxSXsYMA3aWuAfigeqeOOQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\qxSXsYMA3aWuAfigeqeOOQ.jpg'
# Skipping corrupted image 74upe0h6XxwgzqpdnAh_7Q.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\74upe0h6XxwgzqpdnAh_7Q.jpg'
# Skipping corrupted image 6bKuH4FOdaaPInF9NmlQHQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\6bKuH4FOdaaPInF9NmlQHQ.jpg'
# Skipping corrupted image UG2JuFFa_WxhPEtMOtq-JQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\UG2JuFFa_WxhPEtMOtq-JQ.jpg'
# Skipping corrupted image tSHz7RzlgceAItRejZ396A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\tSHz7RzlgceAItRejZ396A.jpg'
# Skipping corrupted image GPMWGVjuCsa6fadnZsEplw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\GPMWGVjuCsa6fadnZsEplw.jpg'
# Skipping corrupted image RIeulJUzgemFugkkgg4qgA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\RIeulJUzgemFugkkgg4qgA.jpg'
# Skipping corrupted image CA9z96gGA4y9QOes2Y9eGw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\CA9z96gGA4y9QOes2Y9eGw.jpg'
# Skipping corrupted image amM65inTV6wvx0NNZN5qhg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\amM65inTV6wvx0NNZN5qhg.jpg'
# Skipping corrupted image C6n0nKVbgLbYmxSiQ_bFsg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\C6n0nKVbgLbYmxSiQ_bFsg.jpg'
# Skipping corrupted image j5-4lzg23yGECBa6l1fyRQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\j5-4lzg23yGECBa6l1fyRQ.jpg'
# Skipping corrupted image gJH0d6Sut4eZDlbV0GCByg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\gJH0d6Sut4eZDlbV0GCByg.jpg'
# Skipping corrupted image hChXG-gGWxzGvalse3EYmw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\hChXG-gGWxzGvalse3EYmw.jpg'
# Skipping corrupted image VSekUmmsGZcX7KaPe_hXyw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\VSekUmmsGZcX7KaPe_hXyw.jpg'
# Skipping corrupted image 9BvYOtforBBP6MvvDogtmw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\9BvYOtforBBP6MvvDogtmw.jpg'
# Skipping corrupted image rIhUkEmP-j4NcQVW3YuPYQ.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\rIhUkEmP-j4NcQVW3YuPYQ.jpg'
# Skipping corrupted image NfayhoTudVJQsEF-XlPyjw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\NfayhoTudVJQsEF-XlPyjw.jpg'
# Skipping corrupted image m3oIKhKKCQD54y1E-dBKSw.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\m3oIKhKKCQD54y1E-dBKSw.jpg'
# Skipping corrupted image cwwoZcpqdu2MwdDusNyTdg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\cwwoZcpqdu2MwdDusNyTdg.jpg'
# Skipping corrupted image DB7BlUpO4LAmC1lCN62hqg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\DB7BlUpO4LAmC1lCN62hqg.jpg'
# Skipping corrupted image ARwqGQZaT0p-XpYYjMXgQg.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\ARwqGQZaT0p-XpYYjMXgQg.jpg'
# Skipping corrupted image 9jBH61ndIcsheo6FtIHArA.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\9jBH61ndIcsheo6FtIHArA.jpg'
# Skipping corrupted image iX-8Xm2G7meRHUg8qhoL1A.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\iX-8Xm2G7meRHUg8qhoL1A.jpg'
# Skipping corrupted image GWLmPwKeBnh2b_7Kv_LQ7w.jpg: cannot identify image file 'C:\\Users\\arshi\\Desktop\\AI & DS\\Term3\\DL\\Assignments\\Graded4\\photos\\GWLmPwKeBnh2b_7Kv_LQ7w.jpg'
# Found 108047 valid images with label 'food'

# %% [markdown]
# ## Base Model

# %%
subset_indices = random.sample(range(len(dataset)), min(7000, len(dataset))) 
subset = Subset(dataset, subset_indices)
dataloader = DataLoader(subset, batch_size=64, shuffle=True)

# %%
# Generator Model
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 128 * 128 * 3),  # Output size for 128x128x3 image
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), 3, 128, 128)  # Reshape to 128x128x3
        return img

# %%
# Discriminator Model
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(128 * 128 * 3, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1)
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)  # Flatten 128x128x3 images
        validity = self.model(img_flat)
        return validity

# %%
latent_dim = 100
generator_base = Generator(latent_dim).cuda()
discriminator_base = Discriminator().cuda()

# %%
optimizer_G = optim.RMSprop(generator_base.parameters(), lr=0.0002)
optimizer_D = optim.RMSprop(discriminator_base.parameters(), lr=0.0002)

# %%
# Training Loop
n_epochs = 50
n_critic = 5

# %%
for epoch in range(n_epochs):
    for i, imgs in enumerate(dataloader):
        real_imgs = imgs.cuda()

        # Train Discriminator
        optimizer_D.zero_grad()
        z = torch.randn(imgs.size(0), latent_dim).cuda()
        fake_imgs = generator_base(z).detach()
        loss_D = -torch.mean(discriminator_base(real_imgs)) + torch.mean(discriminator_base(fake_imgs))
        loss_D.backward()
        optimizer_D.step()

        # Clip discriminator weights
        for p in discriminator_base.parameters():
            p.data.clamp_(-0.01, 0.01)

        # Train Generator every n_critic steps
        if i % n_critic == 0:
            optimizer_G.zero_grad()
            gen_imgs = generator_base(z)
            loss_G = -torch.mean(discriminator_base(gen_imgs))
            loss_G.backward()
            optimizer_G.step()

    print(f"[Epoch {epoch + 1}/{n_epochs}] Loss_D: {loss_D.item():.4f} Loss_G: {loss_G.item():.4f}")
# Out:
# [Epoch 1/50] Loss_D: -477.4080 Loss_G: -34.0941
# [Epoch 2/50] Loss_D: 5.7556 Loss_G: -22.5922
# [Epoch 3/50] Loss_D: 13.2684 Loss_G: 751.8094
# [Epoch 4/50] Loss_D: -168.6426 Loss_G: 600.5760
# [Epoch 5/50] Loss_D: -43.3712 Loss_G: -271.5732
# [Epoch 6/50] Loss_D: -111.4825 Loss_G: 60.4431
# [Epoch 7/50] Loss_D: -85.2946 Loss_G: -19.3190
# [Epoch 8/50] Loss_D: 16.2351 Loss_G: -9.0795
# [Epoch 9/50] Loss_D: -186.2119 Loss_G: 9.2792
# [Epoch 10/50] Loss_D: -288.0344 Loss_G: -39.6688
# [Epoch 11/50] Loss_D: -54.9304 Loss_G: -169.4471
# [Epoch 12/50] Loss_D: -63.5950 Loss_G: 4.9419
# [Epoch 13/50] Loss_D: -127.1321 Loss_G: -23.5435
# [Epoch 14/50] Loss_D: -141.1325 Loss_G: 124.8398
# [Epoch 15/50] Loss_D: -150.9208 Loss_G: 129.3078
# [Epoch 16/50] Loss_D: -122.1177 Loss_G: 78.3114
# [Epoch 17/50] Loss_D: -154.2849 Loss_G: 121.1209
# [Epoch 18/50] Loss_D: -109.7233 Loss_G: -5.3295
# [Epoch 19/50] Loss_D: -164.2349 Loss_G: 62.6661
# [Epoch 20/50] Loss_D: -108.1168 Loss_G: 47.1091
# [Epoch 21/50] Loss_D: -106.2515 Loss_G: -5.4526
# [Epoch 22/50] Loss_D: -150.0365 Loss_G: 35.5144
# [Epoch 23/50] Loss_D: -116.6509 Loss_G: 99.2027
# [Epoch 24/50] Loss_D: -115.6726 Loss_G: 0.7786
# [Epoch 25/50] Loss_D: -100.0456 Loss_G: -29.1145
# [Epoch 26/50] Loss_D: -132.1610 Loss_G: 66.9700
# [Epoch 27/50] Loss_D: -131.8726 Loss_G: 28.7181
# [Epoch 28/50] Loss_D: -110.9618 Loss_G: 36.0319
# [Epoch 29/50] Loss_D: -53.5690 Loss_G: 84.4012
# [Epoch 30/50] Loss_D: -69.5882 Loss_G: 53.2308
# [Epoch 31/50] Loss_D: -110.9336 Loss_G: 65.4406
# [Epoch 32/50] Loss_D: -174.1211 Loss_G: 57.2054
# [Epoch 33/50] Loss_D: -82.5407 Loss_G: 29.5121
# [Epoch 34/50] Loss_D: -92.9223 Loss_G: 56.1826
# [Epoch 35/50] Loss_D: -96.7138 Loss_G: 54.4511
# [Epoch 36/50] Loss_D: -78.1313 Loss_G: 56.6002
# [Epoch 37/50] Loss_D: -115.5848 Loss_G: 77.9043
# [Epoch 38/50] Loss_D: -85.3082 Loss_G: 45.7064
# [Epoch 39/50] Loss_D: -105.6383 Loss_G: 26.5678
# [Epoch 40/50] Loss_D: -163.4240 Loss_G: 54.5938
# [Epoch 41/50] Loss_D: -96.5183 Loss_G: 46.3719
# [Epoch 42/50] Loss_D: -93.8241 Loss_G: 59.5559
# [Epoch 43/50] Loss_D: -117.2299 Loss_G: 41.2072
# [Epoch 44/50] Loss_D: -78.6464 Loss_G: 6.2734
# [Epoch 45/50] Loss_D: -93.9668 Loss_G: 9.9213
# [Epoch 46/50] Loss_D: -69.9711 Loss_G: 13.5832
# [Epoch 47/50] Loss_D: -59.5378 Loss_G: 33.2877
# [Epoch 48/50] Loss_D: -119.3237 Loss_G: -13.9727
# [Epoch 49/50] Loss_D: -83.4782 Loss_G: 33.1602
# [Epoch 50/50] Loss_D: -85.8404 Loss_G: -26.4675

# %%
# Visualize Generated Images
def show_generated_images(generator, latent_dim, n_images=16):
    generator.eval()
    z = torch.randn(n_images, latent_dim).cuda()
    gen_imgs = generator(z).detach().cpu().numpy()
    gen_imgs = 0.5 * gen_imgs + 0.5  # Rescale to [0, 1]
    
    fig, axs = plt.subplots(4, 4, figsize=(8, 8))
    cnt = 0
    for i in range(4):
        for j in range(4):
            axs[i, j].imshow(np.transpose(gen_imgs[cnt], (1, 2, 0)))
            axs[i, j].axis('off')
            cnt += 1
    plt.show()

# %%
# Display generated images
show_generated_images(generator_base, latent_dim)

# %%
torch.save(generator_base.state_dict(), "saved_models/generator_base_epoch_50.pth")
torch.save(discriminator_base.state_dict(), "saved_models/discriminator_base_epoch_50.pth")

# %% [markdown]
# ### Base Model - Evaluation

# %%
# Initialize the FID metric
fid_metric = FrechetInceptionDistance()

# Function to resize and normalize images to [0, 1] for FID
def preprocess_for_fid(images):
    images_resized = torch.stack([F.resize(img, (299, 299)) for img in images])
    return images_resized.clamp(0, 1)  # Ensure values are in the [0, 1] range

# Function to compute FID
def compute_fid(generator, dataloader, latent_dim, device, num_samples=5000, batch_size=64):
    generator.eval()
    fid_metric.to(device)

    # Add real images to FID metric
    for real_imgs in dataloader:
        real_imgs = real_imgs.to(device)
        real_imgs_resized = preprocess_for_fid(real_imgs)
        fid_metric.update(real_imgs_resized, is_real=True)

    # Generate fake images and add to FID metric
    with torch.no_grad():
        for _ in range(num_samples // batch_size):
            z = torch.randn(batch_size, latent_dim, device=device)
            gen_imgs = generator(z)
            gen_imgs = (gen_imgs + 1) / 2  # Rescale [-1, 1] to [0, 1]
            gen_imgs_resized = preprocess_for_fid(gen_imgs)
            fid_metric.update(gen_imgs_resized, is_real=False)

    fid_score = fid_metric.compute()
    fid_metric.reset()
    generator.train()

    return fid_score.item()
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to C:\Users\arshi/.cache\torch\hub\checkpoints\inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:17<00:00, 6.27MB/s]

# %%
# Evaluate FID
latent_dim = 100  # Ensure this matches your generator's latent dimension
num_samples = 1000  # Number of images to evaluate
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Calculating Fréchet Inception Distance...")
fid_score = compute_fid(generator_base, dataloader, latent_dim, device, num_samples=num_samples)
print(f"FID Score: {fid_score:.4f}")
# Out:
# Calculating Fréchet Inception Distance...
# FID Score: 363.5993

# %%
import torch
from torch.nn.functional import softmax
from torchvision.models import inception_v3
from torchvision.transforms import functional as F
from torch.utils.data import DataLoader
from tqdm import tqdm

# Function to preprocess images for InceptionV3
def preprocess_for_inception(images):
    images_resized = torch.stack([F.resize(img, (299, 299)) for img in images])
    images_normalized = (images_resized - 0.5) / 0.5  # Normalize to [-1, 1]
    return images_normalized

# Function to compute Inception Score
def compute_inception_score(generator, latent_dim, device, num_samples=5000, batch_size=64, splits=10):
    generator.eval()
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()

    preds = []
    with torch.no_grad():
        for _ in tqdm(range(num_samples // batch_size), desc="Generating Images for IS"):
            # Generate fake images
            z = torch.randn(batch_size, latent_dim, device=device)
            gen_imgs = generator(z)
            gen_imgs = (gen_imgs + 1) / 2  # Rescale [-1, 1] to [0, 1]

            # Preprocess images for InceptionV3
            gen_imgs_preprocessed = preprocess_for_inception(gen_imgs).to(device)

            # Get predictions from InceptionV3
            logits = inception_model(gen_imgs_preprocessed)
            preds.append(softmax(logits, dim=1).cpu().numpy())

    preds = np.concatenate(preds, axis=0)

    # Compute IS
    split_scores = []
    for i in range(splits):
        part = preds[i * (num_samples // splits): (i + 1) * (num_samples // splits), :]
        py = np.mean(part, axis=0)
        scores = part * (np.log(part) - np.log(py))
        split_scores.append(np.exp(np.mean(np.sum(scores, axis=1))))

    inception_score = np.mean(split_scores)
    std = np.std(split_scores)

    generator.train()
    return inception_score, std

# Evaluate Inception Score
latent_dim = 100  # Ensure this matches your generator's latent dimension
num_samples = 1000  # Number of images to evaluate
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Calculating Inception Score...")
inception_score, inception_std = compute_inception_score(generator_base, latent_dim, device, num_samples=num_samples)
print(f"Inception Score: {inception_score:.4f} ± {inception_std:.4f}")
# Out:
# Calculating Inception Score...
# c:\Users\arshi\anaconda3\envs\yelp_image_models\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\arshi\anaconda3\envs\yelp_image_models\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Generating Images for IS: 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# Inception Score: 2.1714 ± 0.1642

# %%
# Save FID and IS results
fid_score = compute_fid(generator_base, dataloader, latent_dim, device, num_samples=num_samples)
print(f"FID Score: {fid_score:.4f}")
with open("metrics.txt", "a") as f:
    f.write(f"FID Score Base Model: {fid_score:.4f}\n")

inception_score, inception_std = compute_inception_score(generator_base, latent_dim, device, num_samples=num_samples)
print(f"Inception Score: {inception_score:.4f} ± {inception_std:.4f}")
with open("metrics.txt", "a") as f:
    f.write(f"Inception Score Base Model: {inception_score:.4f} ± {inception_std:.4f}\n")
# Out:
# FID Score: 369.6523
# c:\Users\arshi\anaconda3\envs\yelp_image_models\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\arshi\anaconda3\envs\yelp_image_models\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Generating Images for IS: 100%|██████████| 15/15 [00:02<00:00,  6.11it/s]
# Inception Score: 2.1254 ± 0.0471

# %% [markdown]
# ## Tuning 1

# %% [markdown]
# 1. Adding Gradient penalty
# 2. Learning rate scheduler
# 3. Adding convolutional layers in generator and discriminator
# 4. Added batch normalization in disciminator

# %%
import torch.nn.functional as F

class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()
        
        self.model = nn.Sequential(
            
            nn.ConvTranspose2d(latent_dim, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1),
            nn.Tanh()
        )
        
    def forward(self, z):
        """
        Forward pass of the generator.
        z: Latent vector of shape (batch_size, latent_dim, 1, 1)
        """
        z = z.view(z.size(0), z.size(1), 1, 1)

        img = self.model(z)
        img = F.interpolate(img, size=(128, 128), mode='bilinear', align_corners=False)  # Resize to match real image size
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(256, 1, kernel_size=4, stride=1, padding=0),
        )
    
    def forward(self, img):
        """
        Forward pass of the discriminator.
        img: Input image of shape (batch_size, 3, 128, 128)
        """
        validity = self.model(img)
        return validity.view(-1)  # Flatten for scalar output

# %%
# Instantiate the models
latent_dim = 100  # Dimension of the noise vector (latent space)
generator1 = Generator(latent_dim).to(device)
discriminator1 = Discriminator().to(device)

# %%
def compute_gradient_penalty(discriminator, real_samples, fake_samples, device):
    """
    Computes the gradient penalty for WGAN-GP.
    """
    # Ensure sizes match
    if real_samples.size() != fake_samples.size():
        fake_samples = F.interpolate(fake_samples, size=real_samples.shape[2:], mode='bilinear', align_corners=False)

    alpha = torch.rand(real_samples.size(0), 1, 1, 1, device=device)
    interpolates = (alpha * real_samples + (1 - alpha) * fake_samples).requires_grad_(True)
    
    d_interpolates = discriminator(interpolates)
    gradients = torch.autograd.grad(
        outputs=d_interpolates,
        inputs=interpolates,
        grad_outputs=torch.ones_like(d_interpolates, device=device),
        create_graph=True,
        retain_graph=True,
        only_inputs=True
    )[0]
    
    gradients = gradients.view(gradients.size(0), -1)
    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
    return gradient_penalty

# %%
def discriminator_loss(discriminator, real_images, fake_images, lambda_gp, device):
    """
    Calculates the discriminator loss with gradient penalty.
    """
    real_validity = discriminator(real_images)
    fake_validity = discriminator(fake_images.detach())
    gradient_penalty = compute_gradient_penalty(discriminator, real_images, fake_images, device)
    d_loss = -torch.mean(real_validity) + torch.mean(fake_validity) + lambda_gp * gradient_penalty
    return d_loss

# %%
def generator_loss(discriminator, fake_images):
    """
    Calculates the generator loss.
    """
    g_loss = -torch.mean(discriminator(fake_images))
    return g_loss

# %%
# Hyperparameters
latent_dim = 100
batch_size = 64
lr = 1e-4
beta1, beta2 = 0.0, 0.9
lambda_gp = 10
n_epochs = 75

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate models
generator1 = Generator(latent_dim).to(device)
discriminator1 = Discriminator().to(device)

# Optimizers
g_optimizer = torch.optim.Adam(generator1.parameters(), lr=lr, betas=(beta1, beta2))
d_optimizer = torch.optim.Adam(discriminator1.parameters(), lr=lr, betas=(beta1, beta2))

# Scheduler
scheduler_g = torch.optim.lr_scheduler.StepLR(g_optimizer, step_size=20, gamma=0.5)
scheduler_d = torch.optim.lr_scheduler.StepLR(d_optimizer, step_size=20, gamma=0.5)

# %%
from tqdm import tqdm

for epoch in range(n_epochs):
    for i, real_images in enumerate(dataloader):
        real_images = real_images.to(device)

        # Generate fake images
        z = torch.randn(real_images.size(0), latent_dim, 1, 1, device=device)
        fake_images = generator1(z)

        # Update Discriminator
        d_optimizer.zero_grad()
        loss_D = discriminator_loss(discriminator1, real_images, fake_images, lambda_gp, device)
        loss_D.backward()
        d_optimizer.step()

        # Update Generator
        if i % 5 == 0:  # Update generator less frequently
            g_optimizer.zero_grad()
            z = torch.randn(batch_size, latent_dim, 1, 1, device=device)
            fake_images = generator1(z)
            loss_G = generator_loss(discriminator1, fake_images)
            loss_G.backward()
            g_optimizer.step()
    
    # Step learning rate scheduler
    scheduler_g.step()
    scheduler_d.step()

    # Print losses
    print(f"[Epoch {epoch + 1}/{n_epochs}] Loss_D: {loss_D.item():.4f} Loss_G: {loss_G.item():.4f}")
# Out:
# [Epoch 1/75] Loss_D: 0.8211 Loss_G: -0.0420
# [Epoch 2/75] Loss_D: -0.0406 Loss_G: -0.1133
# [Epoch 3/75] Loss_D: -0.0467 Loss_G: -0.1537
# [Epoch 4/75] Loss_D: 0.1333 Loss_G: -0.1396
# [Epoch 5/75] Loss_D: -0.0522 Loss_G: -0.1139
# [Epoch 6/75] Loss_D: -0.0706 Loss_G: -0.1086
# [Epoch 7/75] Loss_D: -0.0844 Loss_G: -0.1356
# [Epoch 8/75] Loss_D: -0.0479 Loss_G: -0.0291
# [Epoch 9/75] Loss_D: -0.0253 Loss_G: 0.0084
# [Epoch 10/75] Loss_D: -0.0394 Loss_G: -0.0344
# [Epoch 11/75] Loss_D: -0.0474 Loss_G: -0.0769
# [Epoch 12/75] Loss_D: -0.1006 Loss_G: -0.0623
# [Epoch 13/75] Loss_D: -0.0844 Loss_G: 0.0469
# [Epoch 14/75] Loss_D: -0.1000 Loss_G: 0.0035
# [Epoch 15/75] Loss_D: -0.0875 Loss_G: -0.0732
# [Epoch 16/75] Loss_D: -0.0978 Loss_G: -0.1801
# [Epoch 17/75] Loss_D: -0.0889 Loss_G: -0.0800
# [Epoch 18/75] Loss_D: -0.0359 Loss_G: -0.1142
# [Epoch 19/75] Loss_D: 0.0014 Loss_G: -0.1520
# [Epoch 20/75] Loss_D: -0.0870 Loss_G: -0.1445
# [Epoch 21/75] Loss_D: -0.1086 Loss_G: -0.0905
# [Epoch 22/75] Loss_D: -0.1204 Loss_G: -0.0337
# [Epoch 23/75] Loss_D: -0.1105 Loss_G: 0.0308
# [Epoch 24/75] Loss_D: -0.0974 Loss_G: 0.0790
# [Epoch 25/75] Loss_D: -0.0742 Loss_G: 0.1403
# [Epoch 26/75] Loss_D: -0.0543 Loss_G: 0.1743
# [Epoch 27/75] Loss_D: -0.1134 Loss_G: 0.1345
# [Epoch 28/75] Loss_D: -0.1141 Loss_G: 0.1356
# [Epoch 29/75] Loss_D: -0.1199 Loss_G: 0.1555
# [Epoch 30/75] Loss_D: -0.0795 Loss_G: 0.1736
# [Epoch 31/75] Loss_D: -0.1228 Loss_G: 0.1748
# [Epoch 32/75] Loss_D: -0.1150 Loss_G: 0.1937
# [Epoch 33/75] Loss_D: -0.1308 Loss_G: 0.1907
# [Epoch 34/75] Loss_D: -0.1519 Loss_G: 0.1441
# [Epoch 35/75] Loss_D: -0.1496 Loss_G: 0.2002
# [Epoch 36/75] Loss_D: -0.1376 Loss_G: 0.2230
# [Epoch 37/75] Loss_D: -0.1319 Loss_G: 0.2170
# [Epoch 38/75] Loss_D: -0.1423 Loss_G: 0.2269
# [Epoch 39/75] Loss_D: -0.1537 Loss_G: 0.2314
# [Epoch 40/75] Loss_D: -0.1219 Loss_G: 0.2511
# [Epoch 41/75] Loss_D: -0.1703 Loss_G: 0.2332
# [Epoch 42/75] Loss_D: -0.1681 Loss_G: 0.2293
# [Epoch 43/75] Loss_D: -0.1637 Loss_G: 0.2234
# [Epoch 44/75] Loss_D: -0.1817 Loss_G: 0.2462
# [Epoch 45/75] Loss_D: -0.1776 Loss_G: 0.2535
# [Epoch 46/75] Loss_D: -0.1941 Loss_G: 0.2576
# [Epoch 47/75] Loss_D: -0.1457 Loss_G: 0.2438
# [Epoch 48/75] Loss_D: -0.0911 Loss_G: 0.2598
# [Epoch 49/75] Loss_D: -0.1505 Loss_G: 0.2397
# [Epoch 50/75] Loss_D: -0.1869 Loss_G: 0.2549
# [Epoch 51/75] Loss_D: -0.2049 Loss_G: 0.2667
# [Epoch 52/75] Loss_D: -0.1414 Loss_G: 0.2528
# [Epoch 53/75] Loss_D: -0.1919 Loss_G: 0.2420
# [Epoch 54/75] Loss_D: -0.1627 Loss_G: 0.2575
# [Epoch 55/75] Loss_D: -0.2060 Loss_G: 0.2585
# [Epoch 56/75] Loss_D: -0.2318 Loss_G: 0.2576
# [Epoch 57/75] Loss_D: -0.2014 Loss_G: 0.2520
# [Epoch 58/75] Loss_D: -0.2330 Loss_G: 0.2550
# [Epoch 59/75] Loss_D: -0.1918 Loss_G: 0.2777
# [Epoch 60/75] Loss_D: -0.1350 Loss_G: 0.2944
# [Epoch 61/75] Loss_D: -0.2263 Loss_G: 0.2803
# [Epoch 62/75] Loss_D: -0.2463 Loss_G: 0.2692
# [Epoch 63/75] Loss_D: -0.2509 Loss_G: 0.2717
# [Epoch 64/75] Loss_D: -0.2585 Loss_G: 0.2617
# [Epoch 65/75] Loss_D: -0.2554 Loss_G: 0.2725
# [Epoch 66/75] Loss_D: -0.0240 Loss_G: 0.2853
# [Epoch 67/75] Loss_D: -0.2245 Loss_G: 0.2874
# [Epoch 68/75] Loss_D: -0.2515 Loss_G: 0.2944
# [Epoch 69/75] Loss_D: -0.2617 Loss_G: 0.2994
# [Epoch 70/75] Loss_D: -0.0332 Loss_G: 0.3025
# [Epoch 71/75] Loss_D: -0.2554 Loss_G: 0.3130
# [Epoch 72/75] Loss_D: -0.2750 Loss_G: 0.3198
# [Epoch 73/75] Loss_D: -0.2630 Loss_G: 0.3147
# [Epoch 74/75] Loss_D: -0.0916 Loss_G: 0.3237
# [Epoch 75/75] Loss_D: -0.1439 Loss_G: 0.3240

# %%
# Function to visualize generated images
def visualize_generated_images(generator, latent_dim, num_images, device):
    generator.eval()  # Set the generator to evaluation mode
    with torch.no_grad():
        # Generate random latent vectors
        z = torch.randn(num_images, latent_dim, 1, 1, device=device)
        # Generate fake images
        fake_images = generator(z)
        # Denormalize images if needed (assuming [-1, 1] range)
        fake_images = (fake_images + 1) / 2
        # Move images to CPU for visualization
        fake_images = fake_images.cpu()
    # Create a grid of images
    grid = vutils.make_grid(fake_images, nrow=int(num_images**0.5), padding=2, normalize=False)
    # Plot the grid
    plt.figure(figsize=(8, 8))
    plt.axis("off")
    plt.title("Generated Images")
    plt.imshow(grid.permute(1, 2, 0))  # Convert from CHW to HWC for plotting
    plt.show()

# %%
import torch.nn.functional as F

# Example usage
latent_dim = 100  # Set this to match your generator's latent dimension
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
visualize_generated_images(generator1, latent_dim, num_images=16, device=device)

# %%
torch.save(generator1.state_dict(), "saved_models/generator_tuning1_epoch_75.pth")
torch.save(discriminator1.state_dict(), "saved_models/discriminator_tuning1_epoch_75.pth")

# %%
from torchvision.transforms.functional import resize

# Updated Preprocessing Function for FID
def preprocess_for_fid(images):
    images_resized = torch.stack([resize(img, (299, 299)) for img in images])
    images_normalized = images_resized.clamp(0, 1)  # Ensure range [0, 1]
    return images_normalized

# Updated Preprocessing Function for Inception
def preprocess_for_inception(images):
    images_resized = torch.stack([resize(img, (299, 299)) for img in images])
    images_normalized = (images_resized * 2) - 1  # Normalize to [-1, 1]
    return images_normalized

# %%
from torchvision.models import Inception_V3_Weights

inception_model = inception_v3(weights=Inception_V3_Weights.IMAGENET1K_V1, transform_input=False).to(device)

# %%
# Save FID and IS results
fid_score = compute_fid(generator1, dataloader, latent_dim, device, num_samples=num_samples)
print(f"FID Score: {fid_score:.4f}")
with open("metrics.txt", "a") as f:
    f.write(f"FID Score for Tuning 1: {fid_score:.4f}\n")

inception_score, inception_std = compute_inception_score(generator1, latent_dim, device, num_samples=num_samples)
print(f"Inception Score: {inception_score:.4f} ± {inception_std:.4f}")
with open("metrics.txt", "a") as f:
    f.write(f"Inception Score for Tuning 1: {inception_score:.4f} ± {inception_std:.4f}\n")
# Out:
# FID Score: 440.4061
# Generating Images for IS: 100%|██████████| 15/15 [00:02<00:00,  6.12it/s]
# Inception Score: 1.4904 ± 0.0400
